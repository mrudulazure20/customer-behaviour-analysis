# %%
print("hello")
# Out:
# hello

# %%
print("Mrudula")
# Out:
# Mrudula

# %%
print("The world nis beautiful")
# Out:
# The world nis beautiful

# %%
a=4
print("a")
# Out:
# a

# %%
b=7
print(int)
# Out:
# <class 'int'>

# %%
b=8
print("int")
# Out:
# int

# %%
import pandas as pd
df=pd.read_csv('customer_shopping_behavior.csv')

# %%
import pandas as pd

# %%
Customer Shopping Behavior Analysis = pd.read_csv(r"C:\Users\Admin\OneDrive\Documents\Mrudula\"Customer Shopping Behavior Analysis")
# Out:
#   Cell In[2], line 1
#     Customer Shopping Behavior Analysis = pd.read_csv(r"C:\Users\Admin\OneDrive\Documents\Mrudula\"Customer Shopping Behavior Analysis")
#              ^
# SyntaxError: invalid syntax

# %%
print("Mrusula")
# Out:
# Mrusula

# %%
pip install pandas openpyxl
# Out:
# ...
#
#    ---------------------------------------- 0/2 [et-xmlfile]
#    ---------------------------------------- 0/2 [et-xmlfile]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
# ...

# %%
import pandas as pd

df = pd.read_excel(r"C:\Users\Admin\OneDrive\Documents\Mrudula\Customer Shopping Behavior Analysis.xlsx")

df.head()
# Out:
#    Customer id  Age  Gender item purchase  Category  Purchase amount  \
# 0            1    55   Male        Blouse  Clothing               53
# 1            2    19   Male       Sweater  Clothing               64
# 2            3    50   Male         Jeans  Clothing               73
# 3            4    21   Male       Sandals  Footwear               90
# 4            5    45   Male        Blouse  Clothing               49
#
#         location size      color  season  review rating subcription status  \
# 0       Kentucky    L       Gray  Winter            3.1                Yes
# 1          Maine    L     Maroon  Winter            3.1                Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                Yes
# 4         Oregon    M  Turquoise  Spring            2.7                Yes
#
#   ship[ping type discount applied  Promo code used  Previous purchase  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 609 entries, 0 to 608
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer id             609 non-null    int64
#  1   Age                     609 non-null    int64
#  2   Gender                  609 non-null    str
#  3   item purchase           609 non-null    str
#  4   Category                609 non-null    str
#  5   Purchase amount         609 non-null    int64
#  6   location                609 non-null    str
#  7   size                    609 non-null    str
#  8   color                   609 non-null    str
#  9   season                  609 non-null    str
#  10  review rating           594 non-null    float64
#  11  subcription status      609 non-null    str
#  12  ship[ping type          609 non-null    str
#  13  discount applied        609 non-null    str
#  14   Promo code used        609 non-null    str
# ...

# %%
df.describe()
# Out:
#        Customer id        Age   Purchase amount  review rating  \
# count   609.000000  609.000000       609.000000     594.000000
# mean    305.000000   43.954023        59.753695       3.773401
# std     175.947435   15.182373        23.510463       0.715263
# min       1.000000   18.000000        20.000000       2.500000
# 25%     153.000000   31.000000        39.000000       3.200000
# 50%     305.000000   44.000000        60.000000       3.700000
# 75%     457.000000   57.000000        81.000000       4.400000
# max     609.000000   70.000000       100.000000       5.000000
#
#        Previous purchase
# count         609.000000
# mean           26.231527
# std            14.242516
# min             1.000000
# 25%            14.000000
# 50%            26.000000
# 75%            39.000000
# max            50.000000

# %%
df.describe(include='all')
# Out:
#         Customer id        Age  Gender item purchase  Category  \
# count    609.000000  609.000000    609           609       609
# unique          NaN         NaN      1            25         4
# top             NaN         NaN   Male          Coat  Clothing
# freq            NaN         NaN    609            36       259
# mean     305.000000   43.954023    NaN           NaN       NaN
# std      175.947435   15.182373    NaN           NaN       NaN
# min        1.000000   18.000000    NaN           NaN       NaN
# 25%      153.000000   31.000000    NaN           NaN       NaN
# 50%      305.000000   44.000000    NaN           NaN       NaN
# 75%      457.000000   57.000000    NaN           NaN       NaN
# max      609.000000   70.000000    NaN           NaN       NaN
#
#         Purchase amount    location size  color season  review rating  \
# count        609.000000         609  609    609    609     594.000000
# ...

# %%
df.isnull().sum()
# Out:
# Customer id                0
# Age                        0
# Gender                     0
# item purchase              0
# Category                   0
# Purchase amount            0
# location                   0
# size                       0
# color                      0
# season                     0
# review rating             15
# subcription status         0
# ship[ping type             0
# discount applied           0
#  Promo code used           0
# Previous purchase          0
# payment method             0
# frequency 5of purchase     0
# dtype: int64

# %%
df['review rating']=df.groupby('category')['review rating'].transform(lambda x:x.fillna(x.median()))

# %%
df.isnull().sum()
# Out:
# Customer id                0
# Age                        0
# Gender                     0
# item purchase              0
# Category                   0
# Purchase amount            0
# location                   0
# size                       0
# color                      0
# season                     0
# review rating             15
# subcription status         0
# ship[ping type             0
# discount applied           0
#  Promo code used           0
# Previous purchase          0
# payment method             0
# frequency 5of purchase     0
# dtype: int64

# %%
df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(' ','_')
df.columns
# Out:
# Index(['customer_id', 'age_', 'gender', 'item_purchase', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subcription_status', 'ship[ping_type',
#        'discount_applied', '_promo_code_used', 'previous_purchase',
#        'payment_method', 'frequency_5of_purchase'],
#       dtype='str')

# %%
print(df.columns.tolist())
# Out:
# ['customer_id', 'age_', 'gender', 'item_purchase', 'category', 'purchase_amount', 'location', 'size', 'color', 'season', 'review_rating', 'subcription_status', 'ship[ping_type', 'discount_applied', '_promo_code_used', 'previous_purchase', 'payment_method', 'frequency_5of_purchase']

# %%
['Customer ID', ' Age ', 'Gender']
# Out:
# ['Customer ID', ' Age ', 'Gender']

# %%
df.columns = df.columns.str.strip()
print(df.columns.tolist())
# Out:
# ['customer_id', 'age_', 'gender', 'item_purchase', 'category', 'purchase_amount', 'location', 'size', 'color', 'season', 'review_rating', 'subcription_status', 'ship[ping_type', 'discount_applied', '_promo_code_used', 'previous_purchase', 'payment_method', 'frequency_5of_purchase']

# %%
print(df.columns.tolist())
# Out:
# ['customer_id', 'age_', 'gender', 'item_purchase', 'category', 'purchase_amount', 'location', 'size', 'color', 'season', 'review_rating', 'subcription_status', 'ship[ping_type', 'discount_applied', '_promo_code_used', 'previous_purchase', 'payment_method', 'frequency_5of_purchase']

# %%
labels = ['Young Adult','Adult','Middle-aged','Senior']
df['age_group'] = pd.qcut(df['age'],q=4, labels=labels)

# %%
frequency_mapping={
    'Fortnightly':14,
    'Weekly':7,
    'Monthly':30,
    'Quarterly':90,
    'Bi-Weekly':14,
    'Annually':365,
    'Every 3 Months':90
}
df['purchase_frequency_days']=df['frequency_5of_purchases'].mp(frequency_mapping)

# %%
print(df.columns.tolist())
# Out:
# ['customer_id', 'age_', 'gender', 'item_purchase', 'category', 'purchase_amount', 'location', 'size', 'color', 'season', 'review_rating', 'subcription_status', 'ship[ping_type', 'discount_applied', '_promo_code_used', 'previous_purchase', 'payment_method', 'frequency_5of_purchase']

# %%
'purchase_frequency_days'
'frequency_5of_purchases'
# Out:
# 'frequency_5of_purchases'

# %%
df[['frequency_5of_purchase']].head(10)
# Out:
#   frequency_5of_purchase
# 0            Fortnightly
# 1            Fortnightly
# 2                 Weekly
# 3                 Weekly
# 4               Annually
# 5                 Weekly
# 6              Quarterly
# 7                 Weekly
# 8               Annually
# 9              Quarterly

# %%
labels = ['Young Adult', 'Adult', 'Middle_Aged', 'Senior']

df['age_group'] = pd.qcut(df['age_'], q=4, labels=labels)

df[['age_', 'age_group']].head(10)
# Out:
#    age_    age_group
# 0    55  Middle_Aged
# 1    19  Young Adult
# 2    50  Middle_Aged
# 3    21  Young Adult
# 4    45  Middle_Aged
# 5    46  Middle_Aged
# 6    63       Senior
# 7    27  Young Adult
# 8    26  Young Adult
# 9    57  Middle_Aged

# %%
df = df.rename(columns={
    '_promo_code_used': 'promo_code_used'
})

# %%
df[['discount_applied','promo_code_used']].head(10)
# Out:
#   discount_applied promo_code_used
# 0              Yes             Yes
# 1              Yes             Yes
# 2              Yes             Yes
# 3              Yes             Yes
# 4              Yes             Yes
# 5              Yes             Yes
# 6              Yes             Yes
# 7              Yes             Yes
# 8              Yes             Yes
# 9              Yes             Yes

# %%
(df['discount_applied']==df['promo_code_used']).all()
# Out:
# np.True_

# %%
df=df.drop('promo_code_used',axis=1)
df.columns
# Out:
# Index(['customer_id', 'age_', 'gender', 'item_purchase', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subcription_status', 'ship[ping_type',
#        'discount_applied', 'previous_purchase', 'payment_method',
#        'frequency_5of_purchase', 'age_group'],
#       dtype='str')

# %%
pip install psycopg2.binary sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
database = "customer behaviour"

# %%
import pandas as pd
from sqlalchemy import create_engine

# Load data
df = pd.read_csv(r"C:\Users\Admin\OneDrive\Documents\Mrudula\Customer Shopping Behavior Analysis.csv")

# Database connection details
username = "postgres"
password = "pass12@3"
host = "localhost"
port = "5432"
database = "customer_behaviour"

# Create engine
engine = create_engine(
    f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}"
)

# Load data into PostgreSQL
table_name = "customer shopping"

df.to_sql(table_name, engine, if_exists="replace", index=False)

print(f"Data successfully loaded into table '{table_name}'")
# Out:
#   Cell In[11], line 5
#     df = pd.read_csv("C:\Users\Admin\OneDrive\Documents\Mrudula\Customer Shopping Behavior Analysis.csv")
#                      ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
import pandas as pd
from sqlalchemy import create_engine
from urllib.parse import quote_plus

# %%
df = pd.read_csv(
    r"C:\Users\Admin\OneDrive\Documents\Mrudula\Customer Shopping Behavior Analysis.csv"
)

# %%
print(df.head())
# Out:
#   Customer ID,Age,Gender,Item Purchased,Category,Purchase Amount (USD),Location,Size,Color,Season,Review Rating,Subscription Status,Shipping Type,Discount Applied,Promo Code Used,Previous Purchases,Payment Method,Frequency of Purchases
# 0  1,55,Male,Blouse,Clothing,53,Kentucky,L,Gray,W...
# 1  2,19,Male,Sweater,Clothing,64,Maine,L,Maroon,W...
# 2  3,50,Male,Jeans,Clothing,73,Massachusetts,S,Ma...
# 3  4,21,Male,Sandals,Footwear,90,Rhode Island,M,M...
# 4  5,45,Male,Blouse,Clothing,49,Oregon,M,Turquois...

# %%
username = "postgres"
password = quote_plus("pass12@3")
host = "localhost"
port = "5432"
database = "customer_behaviour"

# %%
quote_plus("pass12@3")
# Out:
# 'pass12%403'

# %%
engine = create_engine(
    f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}"
)

# %%
username = "postgres"
password = "pass12@3"
host = "localhost"
port = "5432"
database = "customer_behaviour"

engine = create_engine(
    f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}"
)

# %%
from sqlalchemy import create_engine
from urllib.parse import quote_plus

username = "postgres"
password = quote_plus("pass12@3")
host = "localhost"
port = "5432"
database = "customer_behaviour"

engine = create_engine(
    f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}"
)

# %%
username = ?
password = ?
host = ?
port = ?
engine = create_engine(...)
# Out:
#   Cell In[25], line 1
#     username = ?
#                ^
# SyntaxError: invalid syntax

# %%
username = "postgres"
password = "pass123"
host = "localhost"
port = "5432"
database = "customer_behaviour"
